# %%
import textwrap
string = input('')
k = int(input(''))
div = len(string)//k

def output(string):
    return(list(set(string)))

def merge(outputList):
    string = ""
    for  i in outputList:
        string += i
    print(string[len(string)::-1])
s = (textwrap.fill(string, div))
s = s.splitlines()
for i in range(len(s)):
    list1 = output(s[i])
    merge(list1)

# %%
def merge(outputList):
    string = ""
    for  i in outputList:
        string += i
    print(string[len(string)::-1])

# %%
import textwrap
# string = input('')
string = string1
# # k = int(input(''))
k = 5424
textWrapped = textwrap.fill(string, k)
s = (s.splitlines())
for i in range(len(s)):
    removeDuplicate(s[i])
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7a749517ddc6> in <module>
#       7 textWrapped = textwrap.fill(string, k)
#       8 print(textWrapped)
# ----> 9 s = (s.splitlines())
#      10 # # print(s)
#      11 for i in range(len(s)):
#
# AttributeError: 'list' object has no attribute 'splitlines'

# %%
def removeDuplicate(string):
    string = list(string)
    output = string[0]
    for i in range(0, len(string)):
        if string[i] not in output:
            output += (string[i])
    print(output)

# %%
removeDuplicate('ADA')

# %%
string1 = "..."
k1 = 5424

# %%
\
